# %% [markdown]
# # Wprowadzenie do przetwarzania danych
#
# ## wprowadzenie do jupyter notebook
#
# * komórki typu `markdown`
# * komórki typy `code`
# * skróty klawiaturow
#
# esc - przejscie do trybu polecen
#
# ```
# a - above dodanie u góry komórki
# b - below dodanie u dołu
# m - zmiana markdown
# y - zmiana na code
# ```
# enter - przejscie do trybu edycji
#
# ```
# shift + Enter - wykonanie komórki i przejście do kolejnej (lub tworzy nowa jak brak)
# alt + Enter - wykona i utworzy nowa i przejdzie do niej
# ctrl + Enter - wykona i pozostanie w danej komórce
# ```

# %%
# !dir
# !pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.0 kB ? eta -:--:--
#      -------------------------------------- 61.0/61.0 kB 819.4 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.2/11.5 MB 4.1 MB/s eta 0:00:03
#    -- ------------------------------------- 0.8/11.5 MB 8.1 MB/s eta 0:00:02
#    ------- -------------------------------- 2.3/11.5 MB 16.0 MB/s eta 0:00:01
#    --------------- ------------------------ 4.4/11.5 MB 23.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.6/11.5 MB 28.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.4/11.5 MB 29.8 MB/s eta 0:00:01
#    ------------------------------------- -- 10.7/11.5 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 46.7 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
pd.Series
# Out:
# pandas.core.series.Series

# %%
pd.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
data = ["a", "b", "c", "d"]
series = pd.Series(data)

# %%
series
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
data = {"a": 1, "b": 2, "c": 3}
series = pd.Series(data)
series
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data = [
    {"name": "Ola", "age": 28, "city": "Warszawa"}, 
    {"name": "Łukasz", "age": 32, "city": "Warszawa"}, 
    {"name": "Kamil", "age": 27, "city": "Wrocław"}, 
    {"name": "Rafał", "age": 40, "city": "Warszawa"}, 
]

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      name  age      city
# 0     Ola   28  Warszawa
# 1  Łukasz   32  Warszawa
# 2   Kamil   27   Wrocław
# 3   Rafał   40  Warszawa

# %%
data = {
    "name": ["Ola", "Łukasz"],
    "age": [28, 32],
    "city": ["Warszawa", "Olecko"]
}

# %%
df1 = pd.DataFrame(data)
df1
# Out:
#      name  age      city
# 0     Ola   28  Warszawa
# 1  Łukasz   32    Olecko

# %%
df.head(1)
# Out:
#   name  age      city
# 0  Ola   28  Warszawa

# %%
df.tail(1)
# Out:
#     name  age      city
# 3  Rafał   40  Warszawa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   age     4 non-null      int64
#  2   city    4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 228.0+ bytes

# %%
df.describe()
# Out:
#              age
# count   4.000000
# mean   31.750000
# std     5.909033
# min    27.000000
# 25%    27.750000
# 50%    30.000000
# 75%    34.000000
# max    40.000000

# %%
df.to_csv("klasa.csv", index=False)

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 584F-CC44
#
#  Directory of C:\Users\kurs\workspace
#
# 29.05.2024  11:51    <DIR>          .
# 29.05.2024  11:51    <DIR>          ..
# 29.05.2024  11:26    <DIR>          .idea
# 29.05.2024  11:38    <DIR>          .ipynb_checkpoints
# 29.05.2024  09:38               351 argparse_example.py
# 29.05.2024  10:27    <DIR>          dane
# 28.05.2024  16:30               101 dane.json
# 28.05.2024  15:40                75 data.txt
# 28.05.2024  10:45               448 formatowanie_napisow.py
# 28.05.2024  16:30               600 funkcje_w_pythonie.py
# 28.05.2024  09:40               191 hello_world.py
# 28.05.2024  11:15             1˙782 instrukcje_warunkowe.py
# 28.05.2024  16:37               645 json_example.py
# 29.05.2024  09:54             1˙360 kantor.py
# 29.05.2024  11:52                92 klasa.csv
# 28.05.2024  14:12             2˙103 kolekcje_wbudowane_w_pythona.py
# ...

# %%
# %load klasa.csv
name,age,city
Ola,28,Warszawa
Łukasz,32,Warszawa
Kamil,27,Wrocław
Rafał,40,Warszawa

# %%
# !pip install openpyxl
# Out:
# ...
#    ---------------------------------------- 0.0/250.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/250.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/250.0 kB ? eta -:--:--
#    ------ -------------------------------- 41.0/250.0 kB 326.8 kB/s eta 0:00:01
#    ----------- --------------------------- 71.7/250.0 kB 438.9 kB/s eta 0:00:01
#    -------------------------- ----------- 174.1/250.0 kB 876.1 kB/s eta 0:00:01
#    ---------------------------------------- 250.0/250.0 kB 1.0 MB/s eta 0:00:00
# ...

# %%
df.to_excel("klasa.xlsx", index=False)

# %%
df.to_json("klasa.json", index=False)

# %%
# pip install sqlalchemy

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("sqlite:///example.db")
df.to_sql("klasa", engine, index=False, if_exists="replace")
# Out:
# 4

# %%
df.to_html("klasa.html", index=False)

# %%
# df.to_xml("klasa.html", index=False)

# %%
pd.read_excel("klasa.xlsx")
# Out:
#      name  age      city
# 0     Ola   28  Warszawa
# 1  Łukasz   32  Warszawa
# 2   Kamil   27   Wrocław
# 3   Rafał   40  Warszawa

# %%
pd.read_sql("klasa", engine)
# Out:
#      name  age      city
# 0     Ola   28  Warszawa
# 1  Łukasz   32  Warszawa
# 2   Kamil   27   Wrocław
# 3   Rafał   40  Warszawa

# %%
pd.read_csv("klasa.csv")
# Out:
#      name  age      city
# 0     Ola   28  Warszawa
# 1  Łukasz   32  Warszawa
# 2   Kamil   27   Wrocław
# 3   Rafał   40  Warszawa

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_built_with_meson',
#  '_config',
# ...

# %% [markdown]
# ### proste ćwiczenie
# 1. utworz df ktory zawierac bedzie kolumny: marka, model
# 2. wyeksportuj go do excela (bez indeksu)
# 3. wczytaj go do inngo df

# %%
data = [
    {"name": "Ola", "age": 28, "city": "Warszawa", "salary": 12000}, 
    {"name": "Łukasz", "age": 32, "city": "Warszawa",  "salary": 7000}, 
    {"name": "Kamil", "age": 27, "city": "Wrocław",  "salary": 18000}, 
    {"name": "Rafał", "age": 40, "city": "Warszawa",  "salary": 5000}, 
    {"name": "George", "age": 40, "city": "New York",  "salary": 22000}, 
]

# %%
df = pd.DataFrame(data)
df
# Out:
#      name  age      city  salary
# 0     Ola   28  Warszawa   12000
# 1  Łukasz   32  Warszawa    7000
# 2   Kamil   27   Wrocław   18000
# 3   Rafał   40  Warszawa    5000
# 4  George   40  New York   22000

# %%
df.describe()
# Out:
#              age        salary
# count   5.000000      5.000000
# mean   33.400000  12800.000000
# std     6.308724   7190.271205
# min    27.000000   5000.000000
# 25%    28.000000   7000.000000
# 50%    32.000000  12000.000000
# 75%    40.000000  18000.000000
# max    40.000000  22000.000000

# %% [markdown]
# ### Selekcja danych

# %%
df.age
# Out:
# 0    28
# 1    32
# 2    27
# 3    40
# 4    40
# Name: age, dtype: int64

# %%
df["age"]
# Out:
# 0    28
# 1    32
# 2    27
# 3    40
# 4    40
# Name: age, dtype: int64

# %%
df[["age"]]
# Out:
#    age
# 0   28
# 1   32
# 2   27
# 3   40
# 4   40

# %%
df.loc[1:3]
# Out:
#      name  age      city  salary
# 1  Łukasz   32  Warszawa    7000
# 2   Kamil   27   Wrocław   18000
# 3   Rafał   40  Warszawa    5000

# %%
df.iloc[1:3]
# Out:
#      name  age      city  salary
# 1  Łukasz   32  Warszawa    7000
# 2   Kamil   27   Wrocław   18000

# %%
df.loc[1:3, ["age", "salary"]]
# Out:
#    age  salary
# 1   32    7000
# 2   27   18000
# 3   40    5000

# %%
df.loc[1:3, "age": "salary"]
# Out:
#    age      city  salary
# 1   32  Warszawa    7000
# 2   27   Wrocław   18000
# 3   40  Warszawa    5000

# %%
df.iloc[1:3,1:3]
# Out:
#    age      city
# 1   32  Warszawa
# 2   27   Wrocław

# %%
df["age"] > 39
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# Name: age, dtype: bool

# %%
df[df["age"] > 39]
# Out:
#      name  age      city  salary
# 3   Rafał   40  Warszawa    5000
# 4  George   40  New York   22000

# %%
(df["age"] > 39) & (df["salary"] < 22000)
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# dtype: bool

# %%
df[(df["age"] > 39) & (df["salary"] < 22000)]
# Out:
#     name  age      city  salary
# 3  Rafał   40  Warszawa    5000

# %%
# sortowanie

df.sort_values(by="age")
# Out:
#      name  age      city  salary
# 2   Kamil   27   Wrocław   18000
# 0     Ola   28  Warszawa   12000
# 1  Łukasz   32  Warszawa    7000
# 3   Rafał   40  Warszawa    5000
# 4  George   40  New York   22000

# %%
df.sort_values(by=["age", "salary"], ascending=[True, False])
# Out:
#      name  age      city  salary
# 2   Kamil   27   Wrocław   18000
# 0     Ola   28  Warszawa   12000
# 1  Łukasz   32  Warszawa    7000
# 4  George   40  New York   22000
# 3   Rafał   40  Warszawa    5000

# %%
data = [
    {"name": "Ola", "age": 28,  "salary": 12000}, 
    {"name": "Łukasz", "age": 32, "city": "warszawa",  }, 
    {"name": "Kamil", "age": 27, "city": "Wrocław",  "salary": 18000}, 
    {"name": "Rafał",  "city": "Warszawa",  "salary": 5000}, 
    {"name": "George", "age": 40, "city": "New York",  "salary": 22000}, 
    {"name": "Rafał",  "city": "Warszawa",  "salary": 5000}, 
]

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      name   age   salary      city
# 0     Ola  28.0  12000.0       NaN
# 1  Łukasz  32.0      NaN  warszawa
# 2   Kamil  27.0  18000.0   Wrocław
# 3   Rafał   NaN   5000.0  Warszawa
# 4  George  40.0  22000.0  New York
# 5   Rafał   NaN   5000.0  Warszawa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    6 non-null      object
#  1   age     4 non-null      float64
#  2   salary  5 non-null      float64
#  3   city    5 non-null      object
# dtypes: float64(2), object(2)
# memory usage: 324.0+ bytes

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#      name   age   salary      city
# 0     Ola  28.0  12000.0       NaN
# 1  Łukasz  32.0      NaN  warszawa
# 2   Kamil  27.0  18000.0   Wrocław
# 3   Rafał   NaN   5000.0  Warszawa
# 4  George  40.0  22000.0  New York

# %%
df.dropna()
# Out:
#      name   age   salary      city
# 2   Kamil  27.0  18000.0   Wrocław
# 4  George  40.0  22000.0  New York

# %%
df = df.fillna(
    {
        "age": df["age"].mean(),
        "salary": df["salary"].median(),
        "city": "Unknown"
    }
)

# %%
df["city"] = df["city"].str.capitalize()

# %%
df
# Out:
#      name    age   salary      city
# 0     Ola  28.00  12000.0   Unknown
# 1  Łukasz  32.00  15000.0  Warszawa
# 2   Kamil  27.00  18000.0   Wrocław
# 3   Rafał  31.75   5000.0  Warszawa
# 4  George  40.00  22000.0  New york

# %%
df.dtypes
# Out:
# name       object
# age       float64
# salary    float64
# city       object
# dtype: object

# %%
df["age"].astype(int)
# Out:
# 0    28
# 1    32
# 2    27
# 3    31
# 4    40
# Name: age, dtype: int32

# %%
import numpy as np

# %%
df["age"] = df["age"].astype(np.int8)

# %%
df.dtypes
# Out:
# name       object
# age          int8
# salary    float64
# city       object
# dtype: object

# %% [markdown]
# ### praca z datami

# %%
date_data = {
    "name": ["Anna", "Rafał", "Olek", "Gabi"],
    "birthdate": ["1990-01-01", "1980-02-11", "1972-12-15", "2012-03-16"]
}

# %%
df_dates = pd.DataFrame(date_data)

# %%
df_dates["birthdate"] = pd.to_datetime(df_dates["birthdate"])

# %%
df_dates.dtypes
# Out:
# name                 object
# birthdate    datetime64[ns]
# dtype: object

# %%
df_dates["year"] = df_dates["birthdate"].dt.year
df_dates["month"] = df_dates["birthdate"].dt.month
df_dates["day"] = df_dates["birthdate"].dt.day

# %%
from pandas import Timestamp

# %%
t = Timestamp.now()

# %%
t
# Out:
# Timestamp('2024-05-29 12:43:33.143784')

# %%
t.day
# Out:
# 29

# %%
df_dates
# Out:
#     name  birthdate  year  month  day
# 0   Anna 1990-01-01  1990      1    1
# 1  Rafał 1980-02-11  1980      2   11
# 2   Olek 1972-12-15  1972     12   15
# 3   Gabi 2012-03-16  2012      3   16

# %%
df_dates.dtypes
# Out:
# name                 object
# birthdate    datetime64[ns]
# year                  int32
# month                 int32
# day                   int32
# dtype: object

# %%
df_dates.describe()
# Out:
#                  birthdate         year      month        day
# count                    4     4.000000   4.000000   4.000000
# mean   1988-10-26 00:00:00  1988.500000   4.500000  10.750000
# min    1972-12-15 00:00:00  1972.000000   1.000000   1.000000
# 25%    1978-04-28 12:00:00  1978.000000   1.750000   8.500000
# 50%    1985-01-21 00:00:00  1985.000000   2.500000  13.000000
# 75%    1995-07-21 12:00:00  1995.500000   5.250000  15.250000
# max    2012-03-16 00:00:00  2012.000000  12.000000  16.000000
# std                    NaN    17.310883   5.066228   6.849574

# %%
# optymalizacja pamieci

url = "http://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv"

# %%
df = pd.read_csv(url)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %%
df.memory_usage(deep=True)
# Out:
# Index                        132
# Survived                    7096
# Pclass                      7096
# Name                       65924
# Sex                        47639
# Age                         7096
# Siblings/Spouses Aboard     7096
# Parents/Children Aboard     7096
# Fare                        7096
# dtype: int64

# %%
df.Survived = df.Survived.astype(bool)
df.Pclass = df.Pclass.astype(np.int8)
df["Siblings/Spouses Aboard"] = df["Siblings/Spouses Aboard"].astype(np.int8)
df["Parents/Children Aboard"] = df["Parents/Children Aboard"].astype(np.int8)
df.Age = df.Age.astype(np.int8)
df.Fare = df.Fare.astype(np.int8)
df.Sex = df.Sex.astype("category")

# %%
df.memory_usage(deep=True)
# Out:
# Index                        132
# Survived                     887
# Pclass                       887
# Name                       65924
# Sex                         1103
# Age                          887
# Siblings/Spouses Aboard      887
# Parents/Children Aboard      887
# Fare                         887
# dtype: int64

# %%
df.Sex.astype("category")
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 882      male
# 883    female
# 884    female
# 885      male
# 886      male
# Name: Sex, Length: 887, dtype: category
# Categories (2, object): ['female', 'male']

# %%
df.Fare.max()
# Out:
# 512.3292

# %%
df = pd.read_csv(url, dtype={"Age": np.float16})

# %%
pd.read_csv?
# Out:
# Signature:
# pd.read_csv(
#     filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]',
#     *,
#     sep: 'str | None | lib.NoDefault' = <no_default>,
#     delimiter: 'str | None | lib.NoDefault' = None,
#     header: "int | Sequence[int] | None | Literal['infer']" = 'infer',
#     names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>,
#     index_col: 'IndexLabel | Literal[False] | None' = None,
#     usecols: 'UsecolsArgType' = None,
#     dtype: 'DtypeArg | None' = None,
#     engine: 'CSVEngine | None' = None,
#     converters: 'Mapping[Hashable, Callable] | None' = None,
#     true_values: 'list | None' = None,
#     false_values: 'list | None' = None,
#     skipinitialspace: 'bool' = False,
#     skiprows: 'list[int] | int | Callable[[Hashable], bool] | None' = None,
#     skipfooter: 'int' = 0,
#     nrows: 'int | None' = None,
#     na_values: 'Hashable | Iterable[Hashable] | Mapping[Hashable, Iterable[Hashable]] | None' = None,
# ...

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %%
df["FamilySize"] = df["Siblings/Spouses Aboard"] + df["Parents/Children Aboard"]

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare  \
# ...

# %%
df.columns = ['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibAboard',
       'PCAboard', 'Fare', 'FamilySize']

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  SibAboard  PCAboard     Fare  FamilySize
# ...

# %%
groupe_df = df.groupby("Pclass").agg({"Fare": "mean", "Age":"mean", "FamilySize": "mean"})

# %%
groupe_df.plot(kind="bar")
# Out:
# <Axes: xlabel='Pclass'>

# %%
# !pip install matplotlib

# %%
left_df = pd.DataFrame(
    {
        "key": ["A", "B", "C", "D"],
        "value_left": [1, 2, 3, 4]
    }
)

# %%
right_df = pd.DataFrame(
    {
        "key": ["A", "B", "E", "F"],
        "value_right": [1, 2, 3, 4]
    }
)

# %%
left_df
# Out:
#   key  value_left
# 0   A           1
# 1   B           2
# 2   C           3
# 3   D           4

# %%
right_df
# Out:
#   key  value_right
# 0   A            1
# 1   B            2
# 2   E            3
# 3   F            4

# %%
pd.merge(left_df, right_df, on="key" , how="left")
# Out:
#   key  value_left  value_right
# 0   A           1          1.0
# 1   B           2          2.0
# 2   C           3          NaN
# 3   D           4          NaN

# %%
pd.merge(left_df, right_df, on="key" , how="right")
# Out:
#   key  value_left  value_right
# 0   A         1.0            1
# 1   B         2.0            2
# 2   E         NaN            3
# 3   F         NaN            4

# %%
pd.merge(left_df, right_df, on="key" , how="inner")
# Out:
#   key  value_left  value_right
# 0   A           1            1
# 1   B           2            2

# %%
pd.merge(left_df, right_df, on="key" , how="outer")
# Out:
#   key  value_left  value_right
# 0   A         1.0          1.0
# 1   B         2.0          2.0
# 2   C         3.0          NaN
# 3   D         4.0          NaN
# 4   E         NaN          3.0
# 5   F         NaN          4.0

# %%
pd.merge?
# Out:
# Signature:
# pd.merge(
#     left: 'DataFrame | Series',
#     right: 'DataFrame | Series',
#     how: 'MergeHow' = 'inner',
#     on: 'IndexLabel | AnyArrayLike | None' = None,
#     left_on: 'IndexLabel | AnyArrayLike | None' = None,
#     right_on: 'IndexLabel | AnyArrayLike | None' = None,
#     left_index: 'bool' = False,
#     right_index: 'bool' = False,
#     sort: 'bool' = False,
#     suffixes: 'Suffixes' = ('_x', '_y'),
#     copy: 'bool | None' = None,
#     indicator: 'str | bool' = False,
#     validate: 'str | None' = None,
# ) -> 'DataFrame'
# Docstring:
# Merge DataFrame or named Series objects with a database-style join.
#
# A named Series object is treated as a DataFrame with a single named column.
#
# The join is done on columns or indexes. If joining columns on
# columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
# on indexes or indexes on a column or columns, the index will be passed on.
# ...

# %%
left_df.set_index("key", inplace=True)
right_df.set_index("key", inplace=True)

# %%
left_df.join(right_df, how="outer")
# Out:
#      value_left  value_right
# key
# A           1.0          1.0
# B           2.0          2.0
# C           3.0          NaN
# D           4.0          NaN
# E           NaN          3.0
# F           NaN          4.0

# %%
pd.concat([left_df, right_df], axis=0, ignore_index=True)
# Out:
#    value_left  value_right
# 0         1.0          NaN
# 1         2.0          NaN
# 2         3.0          NaN
# 3         4.0          NaN
# 4         NaN          1.0
# 5         NaN          2.0
# 6         NaN          3.0
# 7         NaN          4.0

# %% [markdown]
# https://jsonplaceholder.typicode.com/posts
